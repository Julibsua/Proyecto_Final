# %%
# Manejo de datos
import pandas as pd
print(" pandas instalado correctamente.")
import numpy as np
print(" numpy instalado correctamente.")

# Visualización de datos
import matplotlib.pyplot as plt
print(" matplotlib instalado correctamente.")
import seaborn as sns
print(" seaborn instalado correctamente.")

# Modelos de Machine Learning
from sklearn.model_selection import train_test_split
print(" train_test_split de scikit-learn instalado correctamente.")
from sklearn.tree import DecisionTreeClassifier, plot_tree
print(" DecisionTreeClassifier instalado correctamente.")
from sklearn.ensemble import RandomForestClassifier
print(" RandomForestClassifier instalado correctamente.")

# Métricas de Evaluación
from sklearn.metrics import accuracy_score, recall_score, f1_score, classification_report
print(" Métricas de evaluación instaladas correctamente.")

# Visualización de Árboles de Decisión
import graphviz
print(" graphviz instalado correctamente.")
import pydotplus
print(" pydotplus instalado correctamente.")
from sklearn.tree import export_graphviz
print(" export_graphviz instalado correctamente.")
from IPython.display import Image
print(" IPython display para gráficos instalado correctamente.")

print("\n Entorno listo para el análisis de datos y modelos de Machine Learning.")
# Out:
#  pandas instalado correctamente.
#  numpy instalado correctamente.
#  matplotlib instalado correctamente.
#  seaborn instalado correctamente.
#  train_test_split de scikit-learn instalado correctamente.
#  DecisionTreeClassifier instalado correctamente.
#  RandomForestClassifier instalado correctamente.
#  Métricas de evaluación instaladas correctamente.
#  graphviz instalado correctamente.
#  pydotplus instalado correctamente.
#  export_graphviz instalado correctamente.
#  IPython display para gráficos instalado correctamente.
#
#  Entorno listo para el análisis de datos y modelos de Machine Learning.

# %%
df = pd.read_csv("MI_ARCHIVO.csv", sep=",")
print(df.shape)  # Verifica cuántos registros quedaron
print(df.head())  # Muestra las primeras filas
# Out:
# (14575, 41)
#     AÑO  CÓDIGO_MUNICIPIO   MUNICIPIO  CÓDIGO_DEPARTAMENTO DEPARTAMENTO  \
# 0  2023              5001    Medellín                    5    Antioquia
# 1  2023              5002   Abejorral                    5    Antioquia
# 2  2023              5004    Abriaquí                    5    Antioquia
# 3  2023              5021  Alejandría                    5    Antioquia
# 4  2023              5030       Amagá                    5    Antioquia
#
#    CÓDIGO_ETC              ETC POBLACIÓN_5_16  TASA_MATRICULACIÓN_5_16  \
# 0      3759.0         Medellín         377562                    96.15
# 1      3758.0  Antioquia (ETC)           3634                    74.38
# 2      3758.0  Antioquia (ETC)            503                    62.62
# 3      3758.0  Antioquia (ETC)            864                    81.37
# 4      3758.0  Antioquia (ETC)           5060                    78.30
#
#    COBERTURA_NETA  ...  REPROBACIÓN  REPROBACIÓN_TRANSICIÓN  \
# ...

# %%
import pandas as pd

# Guardar el archivo CSV
df.to_csv("mi_archivo.csv", index=False, encoding="utf-8")

print("Archivo guardado exitosamente como 'mi_archivo.csv'")
# Out:
# Archivo guardado exitosamente como 'mi_archivo.csv'

# %%
print("\n Estadísticas generales:")
display(df.describe())
# Out:
#  Estadísticas generales:
#                AÑO  CÓDIGO_MUNICIPIO  CÓDIGO_DEPARTAMENTO    CÓDIGO_ETC  \
# count  14575.00000      14575.000000         14575.000000  14575.000000
# mean    2016.99705      38680.683362            38.246930   3542.380894
# std        3.74139      26534.463681            26.548177   1124.715466
# min     2011.00000       5001.000000             5.000000      3.758000
# 25%     2014.00000      15676.000000            15.000000   3769.000000
# 50%     2017.00000      25839.000000            25.000000   3785.000000
# 75%     2020.00000      66456.000000            66.000000   3805.000000
# max     2023.00000      99773.000000            99.000000  10930.000000
#
#        TASA_MATRICULACIÓN_5_16  COBERTURA_NETA  COBERTURA_NETA_TRANSICIÓN  \
# count             14460.000000    14464.000000               14523.000000
# mean                 85.019139       85.600794                  57.722185
# ...

# %%
print(df.info())  # Para verificar los tipos de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14575 entries, 0 to 14574
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   AÑO                          14575 non-null  int64
#  1   CÓDIGO_MUNICIPIO             14575 non-null  int64
#  2   MUNICIPIO                    14575 non-null  object
#  3   CÓDIGO_DEPARTAMENTO          14575 non-null  int64
#  4   DEPARTAMENTO                 14575 non-null  object
#  5   CÓDIGO_ETC                   14575 non-null  float64
#  6   ETC                          14575 non-null  object
#  7   POBLACIÓN_5_16               14569 non-null  object
#  8   TASA_MATRICULACIÓN_5_16      14460 non-null  float64
#  9   COBERTURA_NETA               14464 non-null  float64
#  10  COBERTURA_NETA_TRANSICIÓN    14523 non-null  float64
#  11  COBERTURA_NETA_PRIMARIA      14484 non-null  float64
# ...

# %%
print(df.shape)  # Muestra cuántas filas y columnas tiene el DataFrame
# Out:
# (14575, 41)

# %%
print("\n Normalizando nombres de columnas...")
df.columns = df.columns.str.lower().str.replace(" ", "_")
print(" Nombres de columnas normalizados.\n")
display(df.columns)
# Out:
#  Normalizando nombres de columnas...
#  Nombres de columnas normalizados.
# Index(['año', 'código_municipio', 'municipio', 'código_departamento',
#        'departamento', 'código_etc', 'etc', 'población_5_16',
#        'tasa_matriculación_5_16', 'cobertura_neta',
#        'cobertura_neta_transición', 'cobertura_neta_primaria',
#        'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
#        'cobertura_bruta_transición', 'cobertura_bruta_primaria',
#        'cobertura_bruta_secundaria', 'cobertura_bruta_media',
#        'tamaño_promedio_de_grupo', 'sedes_conectadas_a_internet', 'deserción',
#        'deserción_transición', 'deserción_primaria', 'deserción_secundaria',
#        'deserción_media', 'aprobación', 'aprobación_transición',
#        'aprobación_primaria', 'aprobación_secundaria', 'aprobación_media',
#        'reprobación', 'reprobación_transición', 'reprobación_primaria',
#        'reprobación_secundaria', 'reprobación_media', 'repitencia',
# ...

# %%
from unidecode import unidecode
df.columns = [unidecode(col) for col in df.columns]

# %%
df.rename(columns={"ano": "año"}, inplace=True)

# %%
print(" Nombres de columnas sin tilde.\n")
display(df.columns)
# Out:
#  Nombres de columnas sin tilde.
# Index(['año', 'codigo_municipio', 'municipio', 'codigo_departamento',
#        'departamento', 'codigo_etc', 'etc', 'poblacion_5_16',
#        'tasa_matriculacion_5_16', 'cobertura_neta',
#        'cobertura_neta_transicion', 'cobertura_neta_primaria',
#        'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
#        'cobertura_bruta_transicion', 'cobertura_bruta_primaria',
#        'cobertura_bruta_secundaria', 'cobertura_bruta_media',
#        'tamano_promedio_de_grupo', 'sedes_conectadas_a_internet', 'desercion',
#        'desercion_transicion', 'desercion_primaria', 'desercion_secundaria',
#        'desercion_media', 'aprobacion', 'aprobacion_transicion',
#        'aprobacion_primaria', 'aprobacion_secundaria', 'aprobacion_media',
#        'reprobacion', 'reprobacion_transicion', 'reprobacion_primaria',
#        'reprobacion_secundaria', 'reprobacion_media', 'repitencia',
# ...

# %%
print(df["codigo_municipio"].dtype)
# Out:
# int64

# %%
df["codigo_etc"] = df["codigo_etc"].astype("int64")

# %%
# verificamos la columna que querramos cambiar
print(df["poblacion_5_16"].dtype)
# Out:
# object

# %%
print(df["poblacion_5_16"].unique())
# Out:
# ['377562' '3634' '503' ... '4354' '4697' '25396']

# %%
print(df["poblacion_5_16"].str.contains(r"[^\d]", regex=True).sum())
# Out:
# 926

# %%
df["poblacion_5_16"] = df["poblacion_5_16"].str.replace(r"[^\d.]", "", regex=True)

# %%
df["poblacion_5_16"] = pd.to_numeric(df["poblacion_5_16"], errors="coerce").fillna(0).astype(int)

# %%
print(df["poblacion_5_16"].dtype)
# Out:
# int64

# %%
df["poblacion_5_16"] = df["poblacion_5_16"].astype("int64")

# %%
print(df["poblacion_5_16"].dtype)
# Out:
# int64

# %%
df["poblacion_5_16"] = df["poblacion_5_16"].fillna(0).astype(int)

# %%
# CAMBIA A FLOAT LAS COLUMNAS
cols_a_convertir = ["cobertura_bruta", "cobertura_bruta_primaria", "cobertura_bruta_secundaria"]

for col in cols_a_convertir:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
# VERIFICAMOS LOS CAMBIOS
print("\n Información general del dataset:")
df.info()
# Out:
#  Información general del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14575 entries, 0 to 14574
# Data columns (total 41 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   año                          14575 non-null  int64
#  1   codigo_municipio             14575 non-null  int64
#  2   municipio                    14575 non-null  object
#  3   codigo_departamento          14575 non-null  int64
#  4   departamento                 14575 non-null  object
#  5   codigo_etc                   14575 non-null  int64
#  6   etc                          14575 non-null  object
#  7   poblacion_5_16               14575 non-null  int64
#  8   tasa_matriculacion_5_16      14460 non-null  float64
#  9   cobertura_neta               14464 non-null  float64
#  10  cobertura_neta_transicion    14523 non-null  float64
#  11  cobertura_neta_primaria      14484 non-null  float64
# ...

# %%
print("Valores faltantes por columna:")
print(df.isnull().sum())

print("\nCantidad de filas duplicadas:", df.duplicated().sum())

missing_percentage = (df.isnull().sum() / len(df)) * 100
print("\nPorcentaje de valores faltantes por columna:")
print(missing_percentage)
# Out:
# Valores faltantes por columna:
# año                               0
# codigo_municipio                  0
# municipio                         0
# codigo_departamento               0
# departamento                      0
# codigo_etc                        0
# etc                               0
# poblacion_5_16                    0
# tasa_matriculacion_5_16         115
# cobertura_neta                  111
# cobertura_neta_transicion        52
# cobertura_neta_primaria          91
# cobertura_neta_secundaria        94
# cobertura_neta_media             93
# cobertura_bruta                  68
# cobertura_bruta_transicion       97
# cobertura_bruta_primaria         81
# cobertura_bruta_secundaria       88
# cobertura_bruta_media           127
# tamano_promedio_de_grupo       7003
# sedes_conectadas_a_internet    6807
# desercion                       140
# desercion_transicion            901
# desercion_primaria              240
# desercion_secundaria            268
# ...

# %%
df.fillna(0, inplace=True)

# %%
print("Valores faltantes por columna:")
print(df.isnull().sum())
# Out:
# Valores faltantes por columna:
# año                            0
# codigo_municipio               0
# municipio                      0
# codigo_departamento            0
# departamento                   0
# codigo_etc                     0
# etc                            0
# poblacion_5_16                 0
# tasa_matriculacion_5_16        0
# cobertura_neta                 0
# cobertura_neta_transicion      0
# cobertura_neta_primaria        0
# cobertura_neta_secundaria      0
# cobertura_neta_media           0
# cobertura_bruta                0
# cobertura_bruta_transicion     0
# cobertura_bruta_primaria       0
# cobertura_bruta_secundaria     0
# cobertura_bruta_media          0
# tamano_promedio_de_grupo       0
# sedes_conectadas_a_internet    0
# desercion                      0
# desercion_transicion           0
# desercion_primaria             0
# desercion_secundaria           0
# desercion_media                0
# aprobacion                     0
# ...

# %%
print(f"Registros restantes después de la limpieza: {df.shape[0]}")
# Out:
# Registros restantes después de la limpieza: 14575

# %%
print("\n Tipos de datos en el dataset:")
display(df.dtypes)
# Out:
#  Tipos de datos en el dataset:
# año                              int64
# codigo_municipio                 int64
# municipio                       object
# codigo_departamento              int64
# departamento                    object
# codigo_etc                       int64
# etc                             object
# poblacion_5_16                   int64
# tasa_matriculacion_5_16        float64
# cobertura_neta                 float64
# cobertura_neta_transicion      float64
# cobertura_neta_primaria        float64
# cobertura_neta_secundaria      float64
# cobertura_neta_media           float64
# cobertura_bruta                float64
# cobertura_bruta_transicion     float64
# cobertura_bruta_primaria       float64
# cobertura_bruta_secundaria     float64
# cobertura_bruta_media          float64
# tamano_promedio_de_grupo       float64
# sedes_conectadas_a_internet    float64
# desercion                      float64
# desercion_transicion           float64
# ...

# %%
print(df.isnull().sum())  # Cuenta los valores nulos por columna
# Out:
# año                            0
# codigo_municipio               0
# municipio                      0
# codigo_departamento            0
# departamento                   0
# codigo_etc                     0
# etc                            0
# poblacion_5_16                 0
# tasa_matriculacion_5_16        0
# cobertura_neta                 0
# cobertura_neta_transicion      0
# cobertura_neta_primaria        0
# cobertura_neta_secundaria      0
# cobertura_neta_media           0
# cobertura_bruta                0
# cobertura_bruta_transicion     0
# cobertura_bruta_primaria       0
# cobertura_bruta_secundaria     0
# cobertura_bruta_media          0
# tamano_promedio_de_grupo       0
# sedes_conectadas_a_internet    0
# desercion                      0
# desercion_transicion           0
# desercion_primaria             0
# desercion_secundaria           0
# desercion_media                0
# aprobacion                     0
# aprobacion_transicion          0
# ...

# %%
print(df.columns)
# Out:
# Index(['año', 'codigo_municipio', 'municipio', 'codigo_departamento',
#        'departamento', 'codigo_etc', 'etc', 'poblacion_5_16',
#        'tasa_matriculacion_5_16', 'cobertura_neta',
#        'cobertura_neta_transicion', 'cobertura_neta_primaria',
#        'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
#        'cobertura_bruta_transicion', 'cobertura_bruta_primaria',
#        'cobertura_bruta_secundaria', 'cobertura_bruta_media',
#        'tamano_promedio_de_grupo', 'sedes_conectadas_a_internet', 'desercion',
#        'desercion_transicion', 'desercion_primaria', 'desercion_secundaria',
#        'desercion_media', 'aprobacion', 'aprobacion_transicion',
#        'aprobacion_primaria', 'aprobacion_secundaria', 'aprobacion_media',
#        'reprobacion', 'reprobacion_transicion', 'reprobacion_primaria',
#        'reprobacion_secundaria', 'reprobacion_media', 'repitencia',
#        'repitencia_transicion', 'repitencia_primaria', 'repitencia_secundaria',
# ...

# %%
print(df["departamento"].value_counts())
# Out:
# departamento
# Antioquia                                                   1625
# Boyacá                                                      1599
# Cundinamarca                                                1508
# Santander                                                   1130
# Nariño                                                       832
# Tolima                                                       611
# Bolívar                                                      598
# Cauca                                                        546
# Valle del Cauca                                              546
# Norte de Santander                                           520
# Huila                                                        481
# Chocó                                                        390
# Córdoba                                                      390
# Magdalena                                                    390
# ...

# %%
print("\n Verificando registros duplicados...")
duplicados = df.duplicated().sum()
print(f" Se encontraron {duplicados} registros duplicados.\n")
# Out:
#  Verificando registros duplicados...
#  Se encontraron 0 registros duplicados.

# %%
print("\n Verificando valores nulos...")
columnas_con_nan = df.isnull().sum()
columnas_con_nan = columnas_con_nan[columnas_con_nan > 0].sort_values(ascending=False)
display(columnas_con_nan)
# Out:
#  Verificando valores nulos...
# Series([], dtype: int64)

# %%
def detectar_outliers_iqr(df):
    print("\n Identificando outliers con el método IQR...\n")
    outliers = {}
    for columna in df.select_dtypes(include=['float64', 'int64']):
        Q1 = df[columna].quantile(0.25)
        Q3 = df[columna].quantile(0.75)
        IQR = Q3 - Q1
        limite_inferior = Q1 - 1.5 * IQR
        limite_superior = Q3 + 1.5 * IQR
        outliers[columna] = df[(df[columna] < limite_inferior) | (df[columna] > limite_superior)][columna].count()
    display(pd.DataFrame(outliers, index=["Cantidad de outliers"]))

print(" Listo para detectar valores atípicos...")
detectar_outliers_iqr(df)
# Out:
#  Listo para detectar valores atípicos...
#
#  Identificando outliers con el método IQR...
#                       año  codigo_municipio  codigo_departamento  codigo_etc  \
# Cantidad de outliers    0                 0                    0        1363
#
#                       poblacion_5_16  tasa_matriculacion_5_16  cobertura_neta  \
# Cantidad de outliers            1350                      640             763
#
#                       cobertura_neta_transicion  cobertura_neta_primaria  \
# Cantidad de outliers                        288                      665
#
#                       cobertura_neta_secundaria  ...  reprobacion  \
# Cantidad de outliers                        769  ...           88
#
#                       reprobacion_transicion  reprobacion_primaria  \
# Cantidad de outliers                    2747                   168
#
#                       reprobacion_secundaria  reprobacion_media  repitencia  \
# ...

# %%
print(df.isnull().sum())
# Out:
# año                            0
# codigo_municipio               0
# municipio                      0
# codigo_departamento            0
# departamento                   0
# codigo_etc                     0
# etc                            0
# poblacion_5_16                 0
# tasa_matriculacion_5_16        0
# cobertura_neta                 0
# cobertura_neta_transicion      0
# cobertura_neta_primaria        0
# cobertura_neta_secundaria      0
# cobertura_neta_media           0
# cobertura_bruta                0
# cobertura_bruta_transicion     0
# cobertura_bruta_primaria       0
# cobertura_bruta_secundaria     0
# cobertura_bruta_media          0
# tamano_promedio_de_grupo       0
# sedes_conectadas_a_internet    0
# desercion                      0
# desercion_transicion           0
# desercion_primaria             0
# desercion_secundaria           0
# desercion_media                0
# aprobacion                     0
# aprobacion_transicion          0
# ...

# %%
print(df.describe())
# Out:
#                año  codigo_municipio  codigo_departamento    codigo_etc  \
# count  14575.00000      14575.000000         14575.000000  14575.000000
# mean    2016.99705      38680.683362            38.246930   3542.320480
# std        3.74139      26534.463681            26.548177   1124.905555
# min     2011.00000       5001.000000             5.000000      3.000000
# 25%     2014.00000      15676.000000            15.000000   3769.000000
# 50%     2017.00000      25839.000000            25.000000   3785.000000
# 75%     2020.00000      66456.000000            66.000000   3805.000000
# max     2023.00000      99773.000000            99.000000  10930.000000
#
#        poblacion_5_16  tasa_matriculacion_5_16  cobertura_neta  \
# count    1.457500e+04             14575.000000    14575.000000
# mean     8.305103e+03                84.348319       84.948878
# std      4.557147e+04                19.892232       18.332900
# min      0.000000e+00                 0.000000        0.000000
# ...

# %%
df["departamento"] = df["departamento"].str.lower().replace({"bogotá, d.c.": "bogotá d.c."})

# %%
palette = ["#4A90E2", "#3D7FBF", "#2C6BA5", "#1B5790", "#0D47A1"]

# %% [markdown]
# Cómo ha evolucionado la matrícula en Bogotá y Atlántico a lo largo de los años

# %% [markdown]
# Consulta de matrícula en Bogotá

# %%
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]
df_bogota_resumen = df_bogota.groupby("año")["tasa_matriculacion_5_16"].mean().reset_index()
print(df_bogota_resumen)
# Out:
#      año  tasa_matriculacion_5_16
# 0   2011                    90.70
# 1   2012                    86.94
# 2   2013                    84.50
# 3   2014                    80.79
# 4   2015                    82.20
# 5   2016                    80.70
# 6   2017                    79.90
# 7   2018                    78.71
# 8   2019                    96.82
# 9   2020                    96.41
# 10  2021                    94.28
# 11  2022                    93.89
# 12  2023                    92.90

# %% [markdown]
# datos atlantico

# %%
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_resumen = df_atlantico.groupby("año")["tasa_matriculacion_5_16"].mean().reset_index()
print(df_atlantico_resumen)
# Out:
#      año  tasa_matriculacion_5_16
# 0   2011                84.176087
# 1   2012                83.763913
# 2   2013                83.764783
# 3   2014                85.226957
# 4   2015                83.102174
# 5   2016                99.095652
# 6   2017               101.156522
# 7   2018               103.127826
# 8   2019                83.815217
# 9   2020                83.854783
# 10  2021                84.335652
# 11  2022                84.418696
# 12  2023                83.640435

# %% [markdown]
# comparativo

# %%
df_comparativo = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_resumen = df_comparativo.groupby(["departamento", "año"])["tasa_matriculacion_5_16"].mean().reset_index()
print(df_comparativo_resumen)
# Out:
#    departamento   año  tasa_matriculacion_5_16
# 0     atlántico  2011                84.176087
# 1     atlántico  2012                83.763913
# 2     atlántico  2013                83.764783
# 3     atlántico  2014                85.226957
# 4     atlántico  2015                83.102174
# 5     atlántico  2016                99.095652
# 6     atlántico  2017               101.156522
# 7     atlántico  2018               103.127826
# 8     atlántico  2019                83.815217
# 9     atlántico  2020                83.854783
# 10    atlántico  2021                84.335652
# 11    atlántico  2022                84.418696
# 12    atlántico  2023                83.640435
# 13  bogotá d.c.  2011                90.700000
# 14  bogotá d.c.  2012                86.940000
# 15  bogotá d.c.  2013                84.500000
# 16  bogotá d.c.  2014                80.790000
# 17  bogotá d.c.  2015                82.200000
# 18  bogotá d.c.  2016                80.700000
# ...

# %% [markdown]
# grasfico de lineas evolucion de matricula por año

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_resumen, x="año", y="tasa_matriculacion_5_16", hue="departamento", marker="o")

# Agregar etiquetas en cada punto
for departamento in df_comparativo_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_resumen[df_comparativo_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["tasa_matriculacion_5_16"]):
        plt.text(x, y, f"{y:.1f}", ha="right", va="bottom", fontsize=10)

plt.title("Evolución de Matrícula en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Matrícula")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# comparacion de matricula por año

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_comparativo_resumen, x="año", y="tasa_matriculacion_5_16", hue="departamento", palette=["#4A90E2", "#0D47A1"])  # Azul claro y azul oscuro

plt.title("Comparativo de Matrícula por Año: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Matrícula")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
heatmap_data = df_comparativo_resumen.pivot(index="departamento", columns="año", values="tasa_matriculacion_5_16")

sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt=".1f", linewidths=0.5)

plt.title("Mapa de Calor: Matrícula Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Departamento")
plt.show()

# %% [markdown]
# Cuál de los dos presenta mayor cobertura educativa?

# %% [markdown]
# Datos de cobertura en Bogotá

# %%
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]
df_bogota_cobertura = df_bogota.groupby("año")["cobertura_neta"].mean().reset_index()
print(df_bogota_cobertura)
# Out:
#      año  cobertura_neta
# 0   2011           90.30
# 1   2012           86.50
# 2   2013           84.10
# 3   2014           92.76
# 4   2015           81.77
# 5   2016           80.26
# 6   2017           79.45
# 7   2018           96.51
# 8   2019           96.30
# 9   2020           95.89
# 10  2021           93.80
# 11  2022           93.37
# 12  2023           92.40

# %% [markdown]
# Datos de cobertura en Atlántico

# %%
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_cobertura = df_atlantico.groupby("año")["cobertura_neta"].mean().reset_index()
print(df_atlantico_cobertura)
# Out:
#      año  cobertura_neta
# 0   2011       84.034783
# 1   2012       83.695652
# 2   2013       83.708696
# 3   2014       88.042609
# 4   2015       83.034348
# 5   2016       98.603478
# 6   2017      100.653913
# 7   2018       83.099130
# 8   2019       83.520870
# 9   2020       83.552609
# 10  2021       84.104783
# 11  2022       84.138696
# 12  2023       83.308261

# %% [markdown]
# comparativo

# %%
df_comparativo_cobertura = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_cobertura_resumen = df_comparativo_cobertura.groupby(["departamento", "año"])["cobertura_neta"].mean().reset_index()
print(df_comparativo_cobertura_resumen)
# Out:
#    departamento   año  cobertura_neta
# 0     atlántico  2011       84.034783
# 1     atlántico  2012       83.695652
# 2     atlántico  2013       83.708696
# 3     atlántico  2014       88.042609
# 4     atlántico  2015       83.034348
# 5     atlántico  2016       98.603478
# 6     atlántico  2017      100.653913
# 7     atlántico  2018       83.099130
# 8     atlántico  2019       83.520870
# 9     atlántico  2020       83.552609
# 10    atlántico  2021       84.104783
# 11    atlántico  2022       84.138696
# 12    atlántico  2023       83.308261
# 13  bogotá d.c.  2011       90.300000
# 14  bogotá d.c.  2012       86.500000
# 15  bogotá d.c.  2013       84.100000
# 16  bogotá d.c.  2014       92.760000
# 17  bogotá d.c.  2015       81.770000
# 18  bogotá d.c.  2016       80.260000
# 19  bogotá d.c.  2017       79.450000
# 20  bogotá d.c.  2018       96.510000
# 21  bogotá d.c.  2019       96.300000
# 22  bogotá d.c.  2020       95.890000
# 23  bogotá d.c.  2021       93.800000
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_cobertura_resumen, x="año", y="cobertura_neta", hue="departamento", marker="o")

# Agregar etiquetas en cada punto
for departamento in df_comparativo_cobertura_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_cobertura_resumen[df_comparativo_cobertura_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["cobertura_neta"]):
        plt.text(x, y, f"{y:.1f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Cobertura Educativa en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Cobertura Neta")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_comparativo_cobertura_resumen, x="año", y="cobertura_neta", hue="departamento", palette=["#4A90E2", "#0D47A1"])  # Azul claro y azul oscuro

plt.title("Comparativo de Cobertura Educativa por Año: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Cobertura Neta")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
heatmap_data = df_comparativo_cobertura_resumen.pivot(index="departamento", columns="año", values="cobertura_neta")

sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt=".1f", linewidths=0.5)

plt.title("Mapa de Calor: Cobertura Educativa Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Departamento")
plt.show()

# %% [markdown]
# Cuál de los dos presenta mayor cobertura educativa?

# %% [markdown]
# cobertura neta promedio por departamento

# %%
df_cobertura = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_cobertura_promedio = df_cobertura.groupby("departamento")["cobertura_neta"].mean().reset_index()
print(df_cobertura_promedio)
# Out:
#   departamento  cobertura_neta
# 0    atlántico       86.422910
# 1  bogotá d.c.       89.493077

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_cobertura_promedio, x="departamento", y="cobertura_neta", hue="departamento", palette=["#4A90E2", "#0D47A1"])  

plt.title("Comparación de Cobertura Educativa: Bogotá vs. Atlántico")
plt.xlabel("Departamento")
plt.ylabel("Cobertura Neta Promedio")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")  # Ajuste de la leyenda
plt.show()
# Out:
# C:\Users\julib\AppData\Local\Temp\ipykernel_8252\22008917.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")  # Ajuste de la leyenda

# %%
# Agrupar los datos para asegurarse de que existe
df_cobertura_por_anio = df.groupby(["departamento", "año"])["cobertura_neta"].mean().reset_index()

# %%
# Crear la figura
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_cobertura_por_anio, x="año", y="cobertura_neta", hue="departamento", marker="o")

# Agregar etiquetas con valores en cada punto
for departamento in df_cobertura_por_anio["departamento"].unique():
    datos_filtrados = df_cobertura_por_anio[df_cobertura_por_anio["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["cobertura_neta"]):
        plt.text(x, y, f"{y:.1f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Cobertura Educativa en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Cobertura Neta")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# Existen períodos donde hay una diferencia significativa en la matrícula entre ambos

# %% [markdown]
# diferencia de matrícula por año

# %%
df_comparativo = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_matricula = df_comparativo.groupby(["departamento", "año"])["tasa_matriculacion_5_16"].mean().reset_index()

# Pivot para comparar directamente
df_pivot = df_matricula.pivot(index="año", columns="departamento", values="tasa_matriculacion_5_16")
df_pivot["diferencia"] = abs(df_pivot["bogotá d.c."] - df_pivot["atlántico"])
print(df_pivot)
# Out:
# departamento   atlántico  bogotá d.c.  diferencia
# año
# 2011           84.176087        90.70    6.523913
# 2012           83.763913        86.94    3.176087
# 2013           83.764783        84.50    0.735217
# 2014           85.226957        80.79    4.436957
# 2015           83.102174        82.20    0.902174
# 2016           99.095652        80.70   18.395652
# 2017          101.156522        79.90   21.256522
# 2018          103.127826        78.71   24.417826
# 2019           83.815217        96.82   13.004783
# 2020           83.854783        96.41   12.555217
# 2021           84.335652        94.28    9.944348
# 2022           84.418696        93.89    9.471304
# 2023           83.640435        92.90    9.259565

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_pivot.index, df_pivot["diferencia"], marker="o", linestyle="-", color="purple")

# Agregar etiquetas con valores en cada punto
for x, y in zip(df_pivot.index, df_pivot["diferencia"]):
    plt.text(x, y, f"{y:.1f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Diferencia de Matrícula entre Bogotá y Atlántico por Año")
plt.xlabel("Año")
plt.ylabel("Diferencia en Tasa de Matrícula")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
umbral = df_pivot["diferencia"].mean() + df_pivot["diferencia"].std()  # Umbral basado en media + desviación estándar
df_significativo = df_pivot[df_pivot["diferencia"] > umbral]
print(df_significativo)
# Out:
# departamento   atlántico  bogotá d.c.  diferencia
# año
# 2016           99.095652        80.70   18.395652
# 2017          101.156522        79.90   21.256522
# 2018          103.127826        78.71   24.417826

# %% [markdown]
#  ¿Cuál es la tasa de deserción en Bogotá vs. Atlántico y qué factores la afectan?

# %% [markdown]
# bogota

# %%
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]
df_bogota_desercion = df_bogota.groupby("año")["desercion"].mean().reset_index()
print(df_bogota_desercion)
# Out:
#      año  desercion
# 0   2011       3.95
# 1   2012       3.89
# 2   2013       3.68
# 3   2014       2.50
# 4   2015       3.63
# 5   2016       2.08
# 6   2017       1.62
# 7   2018       1.65
# 8   2019       1.60
# 9   2020       0.46
# 10  2021       1.29
# 11  2022       3.46
# 12  2023       2.82

# %% [markdown]
# atlantico

# %%
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_desercion = df_atlantico.groupby("año")["desercion"].mean().reset_index()
print(df_atlantico_desercion)
# Out:
#      año  desercion
# 0   2011   2.627391
# 1   2012   3.142174
# 2   2013   2.144348
# 3   2014   2.523478
# 4   2015   1.190870
# 5   2016   2.720000
# 6   2017   1.464348
# 7   2018   2.686087
# 8   2019   2.116522
# 9   2020   2.481739
# 10  2021   2.257826
# 11  2022   2.679130
# 12  2023   2.565217

# %%
df_comparativo_desercion = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_desercion_resumen = df_comparativo_desercion.groupby(["departamento", "año"])["desercion"].mean().reset_index()
print(df_comparativo_desercion_resumen)
# Out:
#    departamento   año  desercion
# 0     atlántico  2011   2.627391
# 1     atlántico  2012   3.142174
# 2     atlántico  2013   2.144348
# 3     atlántico  2014   2.523478
# 4     atlántico  2015   1.190870
# 5     atlántico  2016   2.720000
# 6     atlántico  2017   1.464348
# 7     atlántico  2018   2.686087
# 8     atlántico  2019   2.116522
# 9     atlántico  2020   2.481739
# 10    atlántico  2021   2.257826
# 11    atlántico  2022   2.679130
# 12    atlántico  2023   2.565217
# 13  bogotá d.c.  2011   3.950000
# 14  bogotá d.c.  2012   3.890000
# 15  bogotá d.c.  2013   3.680000
# 16  bogotá d.c.  2014   2.500000
# 17  bogotá d.c.  2015   3.630000
# 18  bogotá d.c.  2016   2.080000
# 19  bogotá d.c.  2017   1.620000
# 20  bogotá d.c.  2018   1.650000
# 21  bogotá d.c.  2019   1.600000
# 22  bogotá d.c.  2020   0.460000
# 23  bogotá d.c.  2021   1.290000
# 24  bogotá d.c.  2022   3.460000
# 25  bogotá d.c.  2023   2.820000

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_desercion_resumen, x="año", y="desercion", hue="departamento", marker="o")

# Agregar etiquetas con los valores en cada punto
for departamento in df_comparativo_desercion_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_desercion_resumen[df_comparativo_desercion_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["desercion"]):
        plt.text(x, y, f"{y:.2f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Deserción Escolar en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Deserción")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_comparativo_desercion_resumen, x="año", y="desercion", hue="departamento", palette=["#4A90E2", "#0D47A1"])  # Azul claro y azul oscuro

plt.title("Comparativo de Deserción Escolar por Año: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Deserción")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
heatmap_data = df_comparativo_desercion_resumen.pivot(index="departamento", columns="año", values="desercion")

sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt=".1f", linewidths=0.5)

plt.title("Mapa de Calor: Deserción Escolar Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Departamento")
plt.show()

# %% [markdown]
# El rendimiento académico es similar en ambos, o hay diferencias marcadas en aprobación y reprobación

# %%
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]
df_bogota_aprobacion = df_bogota.groupby("año")["aprobacion"].mean().reset_index()
print(df_bogota_aprobacion)
# Out:
#      año  aprobacion
# 0   2011       96.05
# 1   2012       96.11
# 2   2013       96.32
# 3   2014       97.36
# 4   2015       96.29
# 5   2016       97.55
# 6   2017       97.29
# 7   2018       98.02
# 8   2019       97.50
# 9   2020       94.40
# 10  2021       88.15
# 11  2022       90.55
# 12  2023       89.40

# %%
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_aprobacion = df_atlantico.groupby("año")["aprobacion"].mean().reset_index()
print(df_atlantico_aprobacion)
# Out:
#      año  aprobacion
# 0   2011   95.747391
# 1   2012   95.963043
# 2   2013   95.455217
# 3   2014   97.328696
# 4   2015   95.646522
# 5   2016   92.581304
# 6   2017   92.532174
# 7   2018   92.898261
# 8   2019   91.319130
# 9   2020   90.213478
# 10  2021   90.543043
# 11  2022   89.593043
# 12  2023   90.261304

# %%
df_bogota_reprobacion = df_bogota.groupby("año")["reprobacion"].mean().reset_index()
print(df_bogota_reprobacion)
# Out:
#      año  reprobacion
# 0   2011         0.00
# 1   2012         0.00
# 2   2013         0.00
# 3   2014         0.14
# 4   2015         0.09
# 5   2016         0.37
# 6   2017         1.09
# 7   2018         0.33
# 8   2019         0.90
# 9   2020         5.14
# 10  2021        10.56
# 11  2022         5.99
# 12  2023         7.78

# %%
df_atlantico_reprobacion = df_atlantico.groupby("año")["reprobacion"].mean().reset_index()
print(df_atlantico_reprobacion)
# Out:
#      año  reprobacion
# 0   2011     1.625652
# 1   2012     0.897391
# 2   2013     2.401304
# 3   2014     0.148261
# 4   2015     3.161739
# 5   2016     4.697826
# 6   2017     6.003478
# 7   2018     4.415217
# 8   2019     6.565217
# 9   2020     7.303913
# 10  2021     7.198696
# 11  2022     7.727391
# 12  2023     7.174783

# %%
df_comparativo_rendimiento = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_rendimiento_resumen = df_comparativo_rendimiento.groupby(["departamento", "año"])[["aprobacion", "reprobacion"]].mean().reset_index()
print(df_comparativo_rendimiento_resumen)
# Out:
#    departamento   año  aprobacion  reprobacion
# 0     atlántico  2011   95.747391     1.625652
# 1     atlántico  2012   95.963043     0.897391
# 2     atlántico  2013   95.455217     2.401304
# 3     atlántico  2014   97.328696     0.148261
# 4     atlántico  2015   95.646522     3.161739
# 5     atlántico  2016   92.581304     4.697826
# 6     atlántico  2017   92.532174     6.003478
# 7     atlántico  2018   92.898261     4.415217
# 8     atlántico  2019   91.319130     6.565217
# 9     atlántico  2020   90.213478     7.303913
# 10    atlántico  2021   90.543043     7.198696
# 11    atlántico  2022   89.593043     7.727391
# 12    atlántico  2023   90.261304     7.174783
# 13  bogotá d.c.  2011   96.050000     0.000000
# 14  bogotá d.c.  2012   96.110000     0.000000
# 15  bogotá d.c.  2013   96.320000     0.000000
# 16  bogotá d.c.  2014   97.360000     0.140000
# 17  bogotá d.c.  2015   96.290000     0.090000
# 18  bogotá d.c.  2016   97.550000     0.370000
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_rendimiento_resumen, x="año", y="aprobacion", hue="departamento", marker="o")

# Agregar etiquetas con los valores en cada punto
for departamento in df_comparativo_rendimiento_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_rendimiento_resumen[df_comparativo_rendimiento_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["aprobacion"]):
        plt.text(x, y, f"{y:.2f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Aprobación Escolar en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Aprobación")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_rendimiento_resumen, x="año", y="reprobacion", hue="departamento", marker="o", palette=["red", "orange"])

# Agregar etiquetas con los valores en cada punto
for departamento in df_comparativo_rendimiento_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_rendimiento_resumen[df_comparativo_rendimiento_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["reprobacion"]):
        plt.text(x, y, f"{y:.2f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Reprobación Escolar en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Reprobación")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_comparativo_rendimiento_resumen, x="año", y="aprobacion", hue="departamento", palette=["#4A90E2", "#0D47A1"])  # Azul claro y azul oscuro

plt.title("Comparativo de Aprobación Escolar por Año: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Aprobación")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_comparativo_rendimiento_resumen, x="año", y="reprobacion", hue="departamento", palette=["#4A90E2", "#0D47A1"])

plt.title("Comparativo de Reprobación Escolar por Año: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Tasa de Reprobación")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
heatmap_data = df_comparativo_rendimiento_resumen.pivot(index="departamento", columns="año", values="aprobacion")

sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt=".1f", linewidths=0.5)

plt.title("Mapa de Calor: Aprobación Escolar Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Departamento")
plt.show()

# %% [markdown]
# Influye la conectividad a internet en la calidad académica

# %%
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]
df_bogota_internet = df_bogota.groupby("año")["sedes_conectadas_a_internet"].mean().reset_index()
print(df_bogota_internet)
# Out:
#      año  sedes_conectadas_a_internet
# 0   2011                        94.21
# 1   2012                       100.00
# 2   2013                        99.86
# 3   2014                        99.86
# 4   2015                        98.87
# 5   2016                        97.65
# 6   2017                        98.76
# 7   2018                         0.00
# 8   2019                         0.00
# 9   2020                         0.00
# 10  2021                         0.00
# 11  2022                         0.00
# 12  2023                         0.00

# %%
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_internet = df_atlantico.groupby("año")["sedes_conectadas_a_internet"].mean().reset_index()
print(df_atlantico_internet)
# Out:
#      año  sedes_conectadas_a_internet
# 0   2011                    71.750000
# 1   2012                    75.023043
# 2   2013                    86.345652
# 3   2014                    86.345652
# 4   2015                    87.166957
# 5   2016                    91.106957
# 6   2017                    91.041304
# 7   2018                     0.000000
# 8   2019                     0.000000
# 9   2020                     0.000000
# 10  2021                     0.000000
# 11  2022                     0.000000
# 12  2023                     0.000000

# %%
df_comparativo_internet = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_internet_resumen = df_comparativo_internet.groupby(["departamento", "año"])[["sedes_conectadas_a_internet", "aprobacion", "reprobacion"]].mean().reset_index()
print(df_comparativo_internet_resumen)
# Out:
#    departamento   año  sedes_conectadas_a_internet  aprobacion  reprobacion
# 0     atlántico  2011                    71.750000   95.747391     1.625652
# 1     atlántico  2012                    75.023043   95.963043     0.897391
# 2     atlántico  2013                    86.345652   95.455217     2.401304
# 3     atlántico  2014                    86.345652   97.328696     0.148261
# 4     atlántico  2015                    87.166957   95.646522     3.161739
# 5     atlántico  2016                    91.106957   92.581304     4.697826
# 6     atlántico  2017                    91.041304   92.532174     6.003478
# 7     atlántico  2018                     0.000000   92.898261     4.415217
# 8     atlántico  2019                     0.000000   91.319130     6.565217
# 9     atlántico  2020                     0.000000   90.213478     7.303913
# 10    atlántico  2021                     0.000000   90.543043     7.198696
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_internet_resumen, x="año", y="sedes_conectadas_a_internet", hue="departamento", marker="o")

# Agregar etiquetas con los valores en cada punto
for departamento in df_comparativo_internet_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_internet_resumen[df_comparativo_internet_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["sedes_conectadas_a_internet"]):
        plt.text(x, y, f"{y:.2f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución de Acceso a Internet en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Porcentaje de Sedes Conectadas a Internet")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_comparativo_internet_resumen, x="sedes_conectadas_a_internet", y="aprobacion", hue="departamento")

plt.title("Relación entre Acceso a Internet y Aprobación Escolar")
plt.xlabel("Porcentaje de Sedes Conectadas")
plt.ylabel("Tasa de Aprobación")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_comparativo_internet_resumen, x="sedes_conectadas_a_internet", y="reprobacion", hue="departamento")

plt.title("Relación entre Acceso a Internet y Reprobación Escolar")
plt.xlabel("Porcentaje de Sedes Conectadas")
plt.ylabel("Tasa de Reprobación")
plt.grid(True)
plt.show()

# %% [markdown]
# Bogotá y Atlántico tienen diferencias en conectividad a internet y cómo afecta los resultados?

# %%
df_comparativo_internet = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]
df_comparativo_internet_resumen = df_comparativo_internet.groupby(["departamento", "año"])[["sedes_conectadas_a_internet", "aprobacion", "reprobacion"]].mean().reset_index()
print(df_comparativo_internet_resumen)
# Out:
#    departamento   año  sedes_conectadas_a_internet  aprobacion  reprobacion
# 0     atlántico  2011                    71.750000   95.747391     1.625652
# 1     atlántico  2012                    75.023043   95.963043     0.897391
# 2     atlántico  2013                    86.345652   95.455217     2.401304
# 3     atlántico  2014                    86.345652   97.328696     0.148261
# 4     atlántico  2015                    87.166957   95.646522     3.161739
# 5     atlántico  2016                    91.106957   92.581304     4.697826
# 6     atlántico  2017                    91.041304   92.532174     6.003478
# 7     atlántico  2018                     0.000000   92.898261     4.415217
# 8     atlántico  2019                     0.000000   91.319130     6.565217
# 9     atlántico  2020                     0.000000   90.213478     7.303913
# 10    atlántico  2021                     0.000000   90.543043     7.198696
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_comparativo_internet_resumen, x="año", y="sedes_conectadas_a_internet", hue="departamento", marker="o")

# Agregar etiquetas con los valores en cada punto
for departamento in df_comparativo_internet_resumen["departamento"].unique():
    datos_filtrados = df_comparativo_internet_resumen[df_comparativo_internet_resumen["departamento"] == departamento]
    for x, y in zip(datos_filtrados["año"], datos_filtrados["sedes_conectadas_a_internet"]):
        plt.text(x, y, f"{y:.2f}", ha="right", va="bottom", fontsize=10, color="black")

plt.title("Evolución del Acceso a Internet en Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Porcentaje de Sedes Conectadas a Internet")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=df_comparativo_internet_resumen, x="sedes_conectadas_a_internet", y="aprobacion", hue="departamento")

plt.title("Relación entre Acceso a Internet y Aprobación Escolar")
plt.xlabel("Porcentaje de Sedes Conectadas")
plt.ylabel("Tasa de Aprobación")
plt.grid(True)
plt.show()

# %%
correlacion_aprobacion = df_comparativo_internet_resumen["sedes_conectadas_a_internet"].corr(df_comparativo_internet_resumen["aprobacion"])
correlacion_reprobacion = df_comparativo_internet_resumen["sedes_conectadas_a_internet"].corr(df_comparativo_internet_resumen["reprobacion"])

print(f"Correlación entre acceso a internet y aprobación: {correlacion_aprobacion:.2f}")
print(f"Correlación entre acceso a internet y reprobación: {correlacion_reprobacion:.2f}")
# Out:
# Correlación entre acceso a internet y aprobación: 0.65
# Correlación entre acceso a internet y reprobación: -0.70

# %% [markdown]
# Los municipios dentro de estos departamentos presentan condiciones atípicas que merecen un análisis más profundo?

# %%
Q1 = df["tasa_matriculacion_5_16"].quantile(0.25)
Q3 = df["tasa_matriculacion_5_16"].quantile(0.75)
IQR = Q3 - Q1

df_atipico_matricula = df[
    (df["tasa_matriculacion_5_16"] < Q1 - 1.5 * IQR) | 
    (df["tasa_matriculacion_5_16"] > Q3 + 1.5 * IQR)
]

print(df_atipico_matricula[["municipio", "departamento", "tasa_matriculacion_5_16"]])
# Out:
#              municipio  departamento  tasa_matriculacion_5_16
# 138    Puerto Colombia     atlántico                   155.14
# 478               Cota  cundinamarca                   186.72
# 487            Fúquene  cundinamarca                   155.74
# 505          La Calera  cundinamarca                   160.56
# 554              Tenjo  cundinamarca                   143.05
# ...                ...           ...                      ...
# 14560        Pana Pana       guainía                    35.70
# 14565       Miraflores      guaviare                    34.48
# 14567           Caruru        vaupés                    20.83
# 14569          Taraira        vaupés                    25.52
# 14571   Puerto Carreño       vichada                   135.90
#
# [640 rows x 3 columns]

# %%
Q1 = df["cobertura_neta"].quantile(0.25)
Q3 = df["cobertura_neta"].quantile(0.75)
IQR = Q3 - Q1

df_atipico_cobertura = df[
    (df["cobertura_neta"] < Q1 - 1.5 * IQR) | 
    (df["cobertura_neta"] > Q3 + 1.5 * IQR)
]

print(df_atipico_cobertura[["municipio", "departamento", "cobertura_neta"]])
# Out:
#              municipio departamento  cobertura_neta
# 15             Armenia    antioquia           49.18
# 63         La Estrella    antioquia          125.01
# 138    Puerto Colombia    atlántico          149.61
# 221             Cubará       boyacá           45.26
# 296             Soracá       boyacá          124.43
# ...                ...          ...             ...
# 14565       Miraflores     guaviare           34.48
# 14567           Caruru       vaupés           20.83
# 14569          Taraira       vaupés           25.52
# 14570         Yavaraté       vaupés           48.67
# 14571   Puerto Carreño      vichada          135.85
#
# [763 rows x 3 columns]

# %%
Q1 = df["aprobacion"].quantile(0.25)
Q3 = df["aprobacion"].quantile(0.75)
IQR = Q3 - Q1

df_atipico_rendimiento = df[
    (df["aprobacion"] < Q1 - 1.5 * IQR) | 
    (df["aprobacion"] > Q3 + 1.5 * IQR)
]

print(df_atipico_rendimiento[["municipio", "departamento", "aprobacion"]])
# Out:
#              municipio     departamento  aprobacion
# 620       La Argentina            huila       77.46
# 1008      Ansermanuevo  valle del cauca       77.64
# 1101        San Felipe          guainía       72.89
# 1102   Puerto Colombia          guainía       70.24
# 1104          Cacahual          guainía       77.68
# ...                ...              ...         ...
# 14557  Puerto Colombia          guainía       71.37
# 14558     La Guadalupe          guainía       70.00
# 14559         Cacahual          guainía       75.30
# 14560        Pana Pana          guainía       58.19
# 14574         Cumaribo          vichada       72.73
#
# [161 rows x 3 columns]

# %%
# Ordenar el dataset por cobertura neta
df_departamentos = df.groupby("departamento")["cobertura_neta"].mean().reset_index()

# Seleccionar los 5 departamentos con mayor y menor cobertura
top_5_altos = df_departamentos.nlargest(5, "cobertura_neta")
top_5_bajos = df_departamentos.nsmallest(5, "cobertura_neta")

# Concatenar los resultados en una tabla final
df_top_cobertura = pd.concat([top_5_altos, top_5_bajos])

# Mostrar la tabla tipo display
from IPython.display import display
display(df_top_cobertura)
# Out:
#    departamento  cobertura_neta
# 26      quindio       94.579615
# 29        sucre       93.849172
# 13        cesar       93.467415
# 21    magdalena       93.044487
# 6   bogotá d.c.       89.493077
# 32       vaupés       54.946216
# 0      amazonas       55.423592
# 17      guainía       56.303009
# 18     guaviare       60.534808
# 23       nariño       77.137248

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

# Crear el gráfico de barras con colores personalizados
sns.barplot(data=df_top_cobertura, x="departamento", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])

# Personalizar etiquetas y título
plt.title("Top 5 Departamentos con Mayor y Menor Cobertura Educativa")
plt.xlabel("Departamento")
plt.ylabel("Cobertura Neta Promedio")
plt.xticks(rotation=45)  # Rotar etiquetas para mejor legibilidad

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\julib\AppData\Local\Temp\ipykernel_8252\602813578.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_top_cobertura, x="departamento", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])
# C:\Users\julib\AppData\Local\Temp\ipykernel_8252\602813578.py:5: UserWarning:
# The palette list has fewer values (2) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=df_top_cobertura, x="departamento", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])

# %%
# Filtrar solo los municipios de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_municipios = df_atlantico.groupby("municipio")["cobertura_neta"].mean().reset_index()

# Obtener el Top 5 con mayor cobertura
top_5_altos = df_atlantico_municipios.nlargest(5, "cobertura_neta")

# Mostrar la tabla tipo display
display(top_5_altos)
# Out:
#            municipio  cobertura_neta
# 13   Puerto Colombia      113.407692
# 1       Barranquilla       99.594615
# 9   Palmar de Varela       95.499231
# 8             Manatí       94.541538
# 20              Suan       93.947692

# %%
# Configurar el tamaño de la figura
plt.figure(figsize=(10, 6))

# Crear el gráfico de barras con colores personalizados
sns.barplot(data=top_5_altos, x="municipio", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])

# Personalizar etiquetas y título
plt.title("Top 5 Municipios con Mayor Cobertura Educativa en Atlántico")
plt.xlabel("Municipio")
plt.ylabel("Cobertura Neta Promedio")
plt.xticks(rotation=45)  # Rotar etiquetas para mejor legibilidad

# Mostrar el gráfico
plt.show()
# Out:
# C:\Users\julib\AppData\Local\Temp\ipykernel_8252\1126551102.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_5_altos, x="municipio", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])
# C:\Users\julib\AppData\Local\Temp\ipykernel_8252\1126551102.py:5: UserWarning:
# The palette list has fewer values (2) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(data=top_5_altos, x="municipio", y="cobertura_neta", palette=["#4A90E2", "#0D47A1"])

# %%
import pandas as pd
from IPython.display import display

# Filtrar solo los municipios de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]
df_atlantico_municipios = df_atlantico.groupby("municipio")["cobertura_neta"].mean().reset_index()

# Obtener el Top 5 con menor cobertura
top_5_bajos = df_atlantico_municipios.nsmallest(5, "cobertura_neta")

# Mostrar la tabla tipo display
display(top_5_bajos)
# Out:
#       municipio  cobertura_neta
# 22     Usiacurí       70.569231
# 17  Santa Lucía       70.870000
# 10        Piojó       74.664615
# 21       Tubará       75.166154
# 18  Santo Tomás       77.445385

# %% [markdown]
# analizar por nivel de escolaridad por cobertura

# %%
print(df.columns)  # Muestra todas las columnas disponibles
# Out:
# Index(['año', 'codigo_municipio', 'municipio', 'codigo_departamento',
#        'departamento', 'codigo_etc', 'etc', 'poblacion_5_16',
#        'tasa_matriculacion_5_16', 'cobertura_neta',
#        'cobertura_neta_transicion', 'cobertura_neta_primaria',
#        'cobertura_neta_secundaria', 'cobertura_neta_media', 'cobertura_bruta',
#        'cobertura_bruta_transicion', 'cobertura_bruta_primaria',
#        'cobertura_bruta_secundaria', 'cobertura_bruta_media',
#        'tamano_promedio_de_grupo', 'sedes_conectadas_a_internet', 'desercion',
#        'desercion_transicion', 'desercion_primaria', 'desercion_secundaria',
#        'desercion_media', 'aprobacion', 'aprobacion_transicion',
#        'aprobacion_primaria', 'aprobacion_secundaria', 'aprobacion_media',
#        'reprobacion', 'reprobacion_transicion', 'reprobacion_primaria',
#        'reprobacion_secundaria', 'reprobacion_media', 'repitencia',
#        'repitencia_transicion', 'repitencia_primaria', 'repitencia_secundaria',
# ...

# %% [markdown]
# covertura por nivel de escolaridad

# %% [markdown]
# transicion

# %%
# Filtrar datos de Bogotá
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]

# Calcular la cobertura neta en transición
df_bogota_cobertura = df_bogota.groupby("año")["cobertura_neta_transicion"].mean().reset_index()

# Mostrar la tabla
display(df_bogota_cobertura)
# Out:
#      año  cobertura_neta_transicion
# 0   2011                      68.60
# 1   2012                      66.30
# 2   2013                      61.20
# 3   2014                      77.96
# 4   2015                      59.17
# 5   2016                      56.39
# 6   2017                      54.62
# 7   2018                      70.65
# 8   2019                      69.11
# 9   2020                      69.15
# 10  2021                      63.99
# 11  2022                      63.40
# 12  2023                      61.43

# %%
# Filtrar datos de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]

# Calcular la cobertura neta en transición
df_atlantico_cobertura = df_atlantico.groupby("año")["cobertura_neta_transicion"].mean().reset_index()

# Mostrar la tabla
display(df_atlantico_cobertura)
# Out:
#      año  cobertura_neta_transicion
# 0   2011                  51.617391
# 1   2012                  56.156522
# 2   2013                  58.526087
# 3   2014                  61.820870
# 4   2015                  57.248261
# 5   2016                  57.452174
# 6   2017                  65.050000
# 7   2018                  56.148261
# 8   2019                  58.179565
# 9   2020                  58.854348
# 10  2021                  56.230000
# 11  2022                  59.084348
# 12  2023                  62.100870

# %%
df_filtrado = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c.", "atlántico"])]

# %%
print(df.head())  # Confirmar que df sigue disponible
# Out:
#     año  codigo_municipio   municipio  codigo_departamento departamento  \
# 0  2023              5001    Medellín                    5    antioquia
# 1  2023              5002   Abejorral                    5    antioquia
# 2  2023              5004    Abriaquí                    5    antioquia
# 3  2023              5021  Alejandría                    5    antioquia
# 4  2023              5030       Amagá                    5    antioquia
#
#    codigo_etc              etc  poblacion_5_16  tasa_matriculacion_5_16  \
# 0        3759         Medellín          377562                    96.15
# 1        3758  Antioquia (ETC)            3634                    74.38
# 2        3758  Antioquia (ETC)             503                    62.62
# 3        3758  Antioquia (ETC)             864                    81.37
# 4        3758  Antioquia (ETC)            5060                    78.30
#
#    cobertura_neta  ...  reprobacion  reprobacion_transicion  \
# ...

# %% [markdown]
# primaria

# %%
# Filtrar datos de Bogotá
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]

# Calcular la cobertura neta en primaria
df_bogota_cobertura = df_bogota.groupby("año")["cobertura_neta_primaria"].mean().reset_index()

# Mostrar la tabla
display(df_bogota_cobertura)
# Out:
#      año  cobertura_neta_primaria
# 0   2011                    87.00
# 1   2012                    84.00
# 2   2013                    79.30
# 3   2014                    88.57
# 4   2015                    78.94
# 5   2016                    79.04
# 6   2017                    78.53
# 7   2018                    97.81
# 8   2019                    96.22
# 9   2020                    93.79
# 10  2021                    89.92
# 11  2022                    87.75
# 12  2023                    86.97

# %%
# Filtrar datos de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]

# Calcular la cobertura neta en primaria
df_atlantico_cobertura = df_atlantico.groupby("año")["cobertura_neta_primaria"].mean().reset_index()

# Mostrar la tabla
display(df_atlantico_cobertura)
# Out:
#      año  cobertura_neta_primaria
# 0   2011                84.708696
# 1   2012                82.591304
# 2   2013                81.895652
# 3   2014                75.375652
# 4   2015                79.773913
# 5   2016                94.135217
# 6   2017                96.097391
# 7   2018                81.163478
# 8   2019                81.756957
# 9   2020                81.933043
# 10  2021                81.572174
# 11  2022                81.796087
# 12  2023                80.365652

# %%
# Agrupar los datos para obtener el promedio anual por departamento
df_agrupado = df_filtrado.groupby(["año", "departamento"])["cobertura_neta_primaria"].mean().reset_index()

plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_agrupado, x="año", y="cobertura_neta_primaria", hue="departamento", marker="o")

# Agregar etiquetas ajustadas en cada punto
for departamento in df_agrupado["departamento"].unique():
    datos_filtrados = df_agrupado[df_agrupado["departamento"] == departamento]
    
    for x, y in zip(datos_filtrados["año"], datos_filtrados["cobertura_neta_primaria"]):
        ajuste = -1.5 if departamento.lower() == "atlántico" else 1.5  # Ajuste dinámico por departamento
        plt.text(x, y + ajuste, f"{y:.2f}", ha="center", va="top", fontsize=9, color="black")

plt.title("Evolución de Cobertura Neta en Primaria: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Cobertura Neta (%)")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.show()

# %% [markdown]
# secundaria

# %%
# Filtrar datos de Bogotá
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]

# Calcular la cobertura neta en secundaria
df_bogota_cobertura = df_bogota.groupby("año")["cobertura_neta_secundaria"].mean().reset_index()

# Mostrar la tabla
display(df_bogota_cobertura)
# Out:
#      año  cobertura_neta_secundaria
# 0   2011                      84.70
# 1   2012                      81.50
# 2   2013                      79.70
# 3   2014                      80.15
# 4   2015                      74.89
# 5   2016                      72.60
# 6   2017                      71.47
# 7   2018                      85.97
# 8   2019                      87.52
# 9   2020                      89.06
# 10  2021                      89.19
# 11  2022                      88.64
# 12  2023                      86.48

# %%
# Filtrar datos de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]

# Calcular la cobertura neta en secundaria
df_atlantico_cobertura = df_atlantico.groupby("año")["cobertura_neta_secundaria"].mean().reset_index()

# Mostrar la tabla
display(df_atlantico_cobertura)
# Out:
#      año  cobertura_neta_secundaria
# 0   2011                  64.252174
# 1   2012                  65.560870
# 2   2013                  66.600000
# 3   2014                  72.681304
# 4   2015                  68.894783
# 5   2016                  80.628696
# 6   2017                  83.212174
# 7   2018                  67.000870
# 8   2019                  66.605217
# 9   2020                  67.410435
# 10  2021                  69.263913
# 11  2022                  69.081739
# 12  2023                  68.716522

# %%
# Agrupar los datos para obtener el promedio anual por departamento
df_agrupado = df_filtrado.groupby(["año", "departamento"])["cobertura_neta_secundaria"].mean().reset_index()

plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_agrupado, x="año", y="cobertura_neta_secundaria", hue="departamento", marker="o")

# Agregar etiquetas ajustadas en cada punto
for departamento in df_agrupado["departamento"].unique():
    datos_filtrados = df_agrupado[df_agrupado["departamento"] == departamento]
    
    for x, y in zip(datos_filtrados["año"], datos_filtrados["cobertura_neta_secundaria"]):
        ajuste = -1.5 if departamento.lower() == "atlántico" else 1.5  # Ajuste dinámico
        plt.text(x, y + ajuste, f"{y:.2f}", ha="center", va="top", fontsize=9, color="black")

plt.title("Evolución de Cobertura Neta en Secundaria: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt.ylabel("Cobertura Neta (%)")
plt.xticks(rotation=45)
plt.legend(title="Departamento", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.show()

# %% [markdown]
# media

# %%
# Filtrar datos de Bogotá
df_bogota = df[df["departamento"].str.lower().isin(["bogotá, d.c.", "bogotá d.c."])]

# Calcular la cobertura neta en educación media
df_bogota_cobertura = df_bogota.groupby("año")["cobertura_neta_media"].mean().reset_index()

# Mostrar la tabla
display(df_bogota_cobertura)
# Out:
#      año  cobertura_neta_media
# 0   2011                 55.00
# 1   2012                 51.80
# 2   2013                 52.70
# 3   2014                 63.51
# 4   2015                 50.61
# 5   2016                 49.73
# 6   2017                 49.30
# 7   2018                 56.01
# 8   2019                 55.49
# 9   2020                 57.30
# 10  2021                 58.84
# 11  2022                 62.05
# 12  2023                 64.42

# %%
# Filtrar datos de Atlántico
df_atlantico = df[df["departamento"].str.lower() == "atlántico"]

# Calcular la cobertura neta en educación media
df_atlantico_cobertura = df_atlantico.groupby("año")["cobertura_neta_media"].mean().reset_index()

# Mostrar la tabla
display(df_atlantico_cobertura)
# Out:
#      año  cobertura_neta_media
# 0   2011             38.395652
# 1   2012             36.608696
# 2   2013             37.830435
# 3   2014             54.394348
# 4   2015             40.329130
# 5   2016             52.310435
# 6   2017             52.347826
# 7   2018             41.354348
# 8   2019             42.564783
# 9   2020             41.600435
# 10  2021             42.738261
# 11  2022             43.383913
# 12  2023             44.195217

# %%
# Agrupar los datos para obtener el promedio anual por departamento
df_agrupado = df_filtrado.groupby(["año", "departamento"])["cobertura_neta_media"].mean().reset_index()

plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=df_agrupado, x="año", y="cobertura_neta_media", hue="departamento", marker="o")

# Agregar etiquetas ajustadas en cada punto
for departamento in df_agrupado["departamento"].unique():
    datos_filtrados = df_agrupado[df_agrupado["departamento"] == departamento]
    
    for x, y in zip(datos_filtrados["año"], datos_filtrados["cobertura_neta_media"]):
        ajuste = -1.5 if departamento.lower() == "atlántico" else 1.5  # Ajuste dinámico
        plt.text(x, y + ajuste, f"{y:.2f}", ha="center", va="top", fontsize=9, color="black")

plt.title("Evolución de Cobertura Neta en Educación Media: Bogotá vs. Atlántico")
plt.xlabel("Año")
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\julib\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages\\matplotlib\\pyplot.py'>
